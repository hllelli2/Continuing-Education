# %% [markdown]
# # Week 10 - Final Project
#
# Welcome to the last week of the course! Well done for making it this far and sticking with it. This week is dedicated to your final project! A task which allows you to apply everything you've learned throughout the course.
#
# As such, there are no new things to learn this week. Give this a good go, and remember to have fun with it! If you don't finish everything, that's okay - all these of these lessons are now yours to revisit whenever you like.

# %% [markdown]
# # Poker 🃚🃖🃁🂭🂺
# ### (Specifically five-card draw)
#
#
# Your task is to create a program that simulates a game of five-card draw poker. The program should allow multiple players to join the game, deal cards, allow players to draw new cards, and determine the winner based on standard poker hand rankings.
#
# #### Requirements:
# 1. **Player Management**: Allow multiple players to join the game. Each player should have a name and a hand of cards.
#
# 2. **Deck of Cards**: Implement a standard 52-card deck. The deck should be shuffled before dealing.
#
# 3. **Dealing Cards**: Deal five cards to each player at the start of the game.
#
# 4. **Drawing Cards**: Allow each player to discard and draw new cards (up to three) from the deck. After the cards are dealt, they should be removed from the deck. At the end of the round, the deck should be reset and reshuffled for the next game.
#
# 5. **Hand Evaluation**: Implement a function to evaluate the hands of each player and determine the winner based on standard poker hand rankings (e.g., pair, two pair, three of a kind, straight, flush, full house, four of a kind, straight flush, royal flush).
#
#
#
# ### Extensions (Optional):
# - **Betting System**: Implement a simple betting system where players can place bets before and after drawing cards.
# -
# - **Testing**: Write unit tests for your card dealing, hand evaluation, and player management functions.
#
# ### Rules:
# - No using modules that directly implement card games or poker logic.
#
# - You may use standard libraries for randomisation, data structures, etc.
#
#
# #### Tips:
# - Break down the project into smaller tasks and tackle them one at a time.
# - Use functions and classes to organize your code effectively.
# - Test your code frequently to catch bugs early.
# - Refer back to previous lessons for guidance on specific concepts.
# - If working from different notebook cells, remember to run all necessary cells to ensure everything is defined.
# - if working with scipts locally, remeber to call the necessary modules.

# %%
# Code Here!

# %% [markdown]
# # Week 8 - Strings, Websites, Images, Email
#
# This week we're going to look at some small miscellaneous stuff that's important to know but doesn't really fit anywhere in the context of the course, as well how we can use Python to interact with the Web, Images and Email. To start, let's look at some basic string manipulation
#
# Python comes with some built in tools for string maniupulation and making our lives a bit easier - we'll look at some built in functionality along with the `re` module for Regex. Finally, we'll look at appling these to some HTML parsing to get some information from the web.
#
# ## Format Strings
#
# Usually when manipulating strings we've done so either using the `+` operator or just passing it in as another argument to the print function as below:

# %%
def say_hello():
    name = input("Please enter your name: ")
    print("Hello,", name)

say_hello()
# Out:
# Hello, Luc

# %% [markdown]
# This is a fine way to do it, and works in a lot of situations, but what about formatting the string to look a bit nicer? We can use `f-strings` to format strings inline:

# %%
def say_hello():
    name = input("Please enter your name: ")
    print(f"Hello, {name}")

say_hello()
# Out:
# Hello, Luc

# %% [markdown]
# This might look like it's just as good as the above - but it comes with some more powerful tools. Consider the following examples:

# %%
import math

name = "Luc Elliott"
other_name = "John T. W. Smith"

# Print pi to 3dp
print(f"Pi is equal to roughly: {math.pi:.3f}")

# Print the name of a variable along with it's value (helpful for debugging!)
print(f"{name=}")

# Force padding for a number (great for tables!):
print(f"Monopoly Scores:\n{'-' * 20}")
print(f"{name:20}== £100")
print(f"{other_name:20}== £2400")
# Out:
# Pi is equal to roughly: 3.142
# name='Luc Elliott'
# Monopoly Scores:
# --------------------
# Luc Elliott         == £100
# John T. W. Smith    == £2400

# %% [markdown]
# ## The Big Scary World of Regex
#
# Regular Expressions (or Regex) are a way of working with text that allows us to search for patterns. Some of you will find this amazing and instantly know a million places where you can use it, and others will wonder why we are talking about this at all!
#
# These expressions look a bit scary and indecipherable, but after a little bit of work I promise you'll be able to figure out what any regular expression is looking for.
#
# Let's start by defining the basic rules and see how they'd be put together. First, if you want to match a single character, we have some basic operations:
#
# * `[abc]` will match a single a, b or c. `[a-m]` will match any character from a to m.
# * `[^abc]` will match any character that's *not* a, b or c.
# * `.` will match any character.
#
# Then for defining *how many* of that character, we have the following basic characters:
# * `*` - zero or more occurences (i.e. optional)
# * `+` - one or more occurances
# * `?` - zero or one occurances
# * `{2}` - exactly 2 occurances (can be any number)
# * `{3, 5}` - exactly 3 to 5 occurances. Leaving out the first number means 0 to the second number - leaving out the second number means "at least the first number".
#
# So, for example, `[abc]+` will match *any* string or substring made up of a, b and cs. `e{2}` will match all `ee`s in the text.
#
# Before moving onto some more complex example, let's see how this works in Python:

# %%
import re

text_to_search = "The rain in spain falls mainly on the plains"

# Search will give the first instance matching the pattern
print(re.search(r"[rpml]ain", text_to_search))

# Findall will give all instances
print(re.findall(r"[rpml]ain", text_to_search))

# One or more letter, followed by 2 ls followed by a letter.
print(re.findall(r"[a-z]+l{2}[a-z]", text_to_search))
# Out:
# <re.Match object; span=(4, 8), match='rain'>
# ['rain', 'pain', 'main', 'lain']
# ['falls']

# %% [markdown]
# With this we can already do a lot of good stuff - we can get even better by adding the following rules:
#
# * `\d \w, \s` are special characters denoting any digit, word, or space respectivly.
# *  A pipe (`|`) allows for "or" groupings of words - for example `(green|red)\sapple` will match both "red apple" and "green apple"
# * \b represents a word boundary (i.e start and end of a word)
# * `^` and `$` match the beginning and end of an input respectivly.
#
# So if we want to get all the rhymes in the above phrase, we can use:

# %%
print(re.findall(r"\b\w{1,2}ain[lys]+\b", text_to_search))
# Out:
# ['mainly', 'plains']

# %% [markdown]
# Regex always takes a bit of trial and error and can be fiddly to get it to work - very often you start simple with the patterns and build them up bit by bit. You'll make complex patterns in no time!
#
# If you want to practice Regex, I recommend [Regex Crosswords](https://regexcrossword.com) or use this [Cheat Sheet](https://www.debuggex.com/cheatsheet/regex/python) - I use this everytime I work with Regex!
#
# Now let's look at a way of using Regex in real life:
#
# ## Input Validation
#
# To validate a postcode using Python we have two options - use an API web service to validate that the postcode is indeed valid and corresponds to an address, or check that it is in the right format manually. The [government actually provides a Regex string](https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/488478/Bulk_Data_Transfer_-_additional_validation_valid_from_12_November_2015.pdf) for postcode matching; this is a bit more complex as it has to handle all the edge cases.
#
# Let's build a function that takes in a string, and scans it for (most) valid postcodes.
#
# Postcodes can take a few forms: 1 or 2 letters followed by 1 or 2 numbers, followed by number, letter, letter.
# This would be fairly difficult to do using normal Python, but far easier using regex!

# %%
def check_for_postcodes(input_string):
    return re.findall(r"[A-Za-z]{1,2}[\d]{1,2}\s?\d[A-Za-z]{1,2}", input_string)

my_string = "Sometimes I write my postcode as SW179EF, sometimes as SW17 9EF."

check_for_postcodes(my_string)
# Out:
# ['SW179EF', 'SW17 9EF']

# %% [markdown]
# ## Web Scraping
#
# Regex is a useful building block for searching for text - and mastery of it will make you very valuable whenever someone wants to look for something; but thankfully for those of us who aren't so comfortable writing out 3 line regex patterns other people have built specific libraries for common tasks.
#
# One such example is web scraping; websites are made of HTML code which looks like the following:
# ```
# <html>
#     <head>Website title</head>
#     <body>Website contents</body>
# <html/>
# ```
# Obviously most website are a bit more complex than this - let's look at the BBC news website for example:

# %%
import requests

bbc = requests.get("https://www.bbc.co.uk/news")
print(bbc.text)
# Out:
# <!DOCTYPE html><html lang="en-GB" class="no-js"><head><meta charSet="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1" /><title data-rh="true">Home - BBC News</title><meta data-rh="true" name="description" content="Visit BBC News for up-to-the-minute news, breaking news, video, audio and feature stories. BBC News provides trusted World and UK news as well as local and regional perspectives. Also entertainment, business, science, technology and health news."/><meta data-rh="true" name="theme-color" content="#FFFFFF"/><meta data-rh="true" property="fb:admins" content="100004154058350"/><meta data-rh="true" property="fb:app_id" content="3662195467332439"/><meta data-rh="true" property="og:description" content="Visit BBC News for up-to-the-minute news, breaking news, video, audio and feature stories. BBC News provides trusted World and UK news as well as local and regional perspectives. Also entertainment, business, science, technology and health news."/><meta data-rh="true" property="og:image" content="https://static.files.bbci.co.uk/core/website/assets/static/news/images/metadata/poster-1024x576.5f404a8b8b.png"/><meta data-rh="true" property="og:image:alt" content="Logo for BBC News"/><meta data-rh="true" property="og:site_name" content="BBC News"/><meta data-rh="true" property="og:title" content="Home - BBC News"/><meta data-rh="true" property="og:type" content="website"/><meta data-rh="true" property="og:url" content="https://www.bbc.co.uk/news"/><meta data-rh="true" name="twitter:card" content="summary_large_image"/><meta data-rh="true" name="twitter:creator" content="@BBCNews"/><meta data-rh="true" name="twitter:description" content="Visit BBC News for up-to-the-minute news, breaking news, video, audio and feature stories. BBC News provides trusted World and UK news as well as local and regional perspectives. Also entertainment, business, science, technology and health news."/><meta data-rh="true" name="twitter:image" content="https://static.files.bbci.co.uk/core/website/assets/static/news/images/metadata/poster-1024x576.5f404a8b8b.png"/><meta data-rh="true" name="twitter:image:alt" content="Logo for BBC News"/><meta data-rh="true" name="twitter:site" content="@BBCNews"/><meta data-rh="true" name="twitter:title" content="Home - BBC News"/><meta data-rh="true" name="twitter:url" content="https://www.bbc.co.uk/news"/><meta data-rh="true" type="metaTags" name="msapplication-TileImage" content="https://static.files.bbci.co.uk/core/website/assets/static/icons/windows-phone/news/windows-phone-icon-270x270.23502b4459.png"/><meta data-rh="true" name="format-detection" content="telephone=no"/><meta data-rh="true" name="robots" content="max-image-preview:large"/><link data-rh="true" rel="canonical" href="https://www.bbc.co.uk/news"/><link data-rh="true" rel="alternate" hrefLang="en" href="https://www.bbc.com/news"/><link data-rh="true" rel="alternate" hrefLang="en-gb" href="https://www.bbc.co.uk/news"/><link data-rh="true" rel="alternate" hrefLang="en-gb" type="application/rss+xml" href="https://feeds.bbci.co.uk/news/rss.xml"/><link data-rh="true" rel="icon" type="image/png" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/news/touch-icon-36.413a37b227.png" sizes="36x36"/><link data-rh="true" rel="icon" type="image/png" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/news/touch-icon-48.010dc96bcf.png" sizes="48x48"/><link data-rh="true" rel="icon" type="image/png" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/news/touch-icon-57.1fcd0dc805.png" sizes="57x57"/><link data-rh="true" rel="icon" type="image/png" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/news/touch-icon-60.52f68a148f.png" sizes="60x60"/><link data-rh="true" rel="icon" type="image/png" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/news/touch-icon-72.f155fdb25f.png" sizes="72x72"/><link data-rh="tru ...
# (() => {
#   if (
#     document.cookie.split(';').some((item) => item.trim().indexOf('ckns_id=') > -1)
#   ) {
#     return;
#   }
#
#
#     function localStorageIsAvailable() {
#       try {
#         const storage = window && window.localStorage;
#         if(typeof storage.getItem === 'function') {
#           return true
#         }
#         return false
#       } catch (error) {
#         return false
#       }
#     }
#
#     if(localStorageIsAvailable()) {
#       var dismissCount = Number(window.localStorage.getItem('sign-in-banner-news-homepage-dismiss-count'));
#
#       if (dismissCount >= 4) {
#         return;
#       }
#
#       var lastDismissedDate = Number(window.localStorage.getItem('sign-in-banner-news-homepage-last-dismissed-date'));
#       var currentTime = Date.now();
#       if (currentTime - lastDismissedDate < 10 * 86400000) {
#         return;
#       }
#     }
#
#   document.querySelector('html').classList.add('display-sign-in-banner');
# })()
# </script><script data-rh="true" data-ist="true" type="text/javascript" nonce="qGZSEGwcAFSRnZUARKTKIp5bC15BE9VIpdmnVtdAvf3aojZFSZ">
#   document.addEventListener(
#     'DOMContentLoaded',
#     () => {
#       const validNations = ['uk', 'england', 'scotland', 'wales', 'northern_ireland'];
#
#       const nation = window.localStorage.getItem('nation_preference');
#
#       if (validNations.includes(nation) && nation !== 'uk') {
#         const containerToDisplay = document.querySelector("#nations-news-" + nation);
#         const containerToHide = document.querySelector("#nations-news-uk");
#
#         if (containerToDisplay) {
#           if (containerToHide) {
#             containerToHide.setAttribute('hidden', '');
#           }
#
#           containerToDisplay.removeAttribute('hidden');
#         }
#       }
#     },
#     { once: true }
#   );
# </script><script nonce="qGZSEGwcAFSRnZUARKTKIp5bC15BE9VIpdmnVtdAvf3aojZFSZ">document.querySelector("html").classList.remove("no-js")</script><style data-emotion="ssrcss-global 1ugndd6">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,main,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block;}:root{interpolate-size:allow-keywords;}body{line-height:1;-webkit-text-size-adjust:none;-moz-text-size-adjust:none;-ms-text-size-adjust:none;text-size-adjust:none;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote::before,blockquote::after,q::before,q::after{content:'';content:none;}table{border-collapse:collapse;border-spacing:0;}button{-webkit-appearance:none;-moz-appearance:none;-ms-appearance:none;appearance:none;margin:0;padding:0;background:none;border-radius:0;border:0;font-family:inherit;color:inherit;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Rg.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Rg.woff) format('woff');font-display:swap;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_It.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_It.woff) format('woff');font-display:swap;font-style:italic;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Bd.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Bd.woff) format('woff');font-display:swap;font-weight:700;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_BdIt.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_BdIt.woff) format('woff');font-display:swap;font-style:italic;font-weight:700;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Lt.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Lt.woff) format('woff');font-display:swap;font-weight:300;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_LtIt.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_LtIt.woff) format('woff');font-display:swap;font-style:italic;font-weight:300;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_ExBd.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_ExBd.woff) format('woff');font-display:swap;font-weight:800;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_ExBdIt.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_ExBdIt.woff) format('woff');font-display:swap;font-style:italic;font-weight:800;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Md.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Md.woff) format('woff');font-display:swap;font-weight:500;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_MdIt.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_MdIt.woff) format('woff');font-display:swap;font-style:italic;font-weig ...
#         0deg,
#         color(from #202224 srgb r g b / 1) 0%,
#         color(from #202224 srgb r g b / 0.95)
#           16%,
#         color(from #202224 srgb r g b / 0) 50%
#       );}}.ssrcss-1nvrp47-Placeholder{display:block;position:relative;background-color:#202224;padding-bottom:177.77777777777777%;}.ssrcss-mi7xqm-StyledHeadingLinkWrapper{padding:16px 0;}@media (min-width: 56.25rem){.ssrcss-mi7xqm-StyledHeadingLinkWrapper{grid-area:heading;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;}}.ssrcss-cegw7a-Container{display:grid;-webkit-column-gap:8px;column-gap:8px;row-gap:8px;grid-template-areas:'heading';}@media (min-width: 37.5rem){.ssrcss-cegw7a-Container{grid-template-columns:35.5rem;}}@media (min-width: 56.25rem){.ssrcss-cegw7a-Container{grid-template-columns:50% 1fr;grid-template-areas:'heading buttons';}}.ssrcss-1rmamhg-Grid{position:relative;width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}@media all and (max-width: 37.4375rem){.ssrcss-1rmamhg-Grid >*{height:auto;margin-top:8px;width:calc(100% / 2 - 4px);}.ssrcss-1rmamhg-Grid >:nth-of-type(1){width:100%;margin-top:0;}.ssrcss-1rmamhg-Grid >:nth-of-type(2n + 2){margin-right:8px;}}@media all and (min-width: 37.5rem){.ssrcss-1rmamhg-Grid >*{height:auto;margin:8px 8px 0 0;width:calc(99.99% / 3 - (16px / 3));}.ssrcss-1rmamhg-Grid >:nth-of-type(1){width:calc(50% - 4px);margin-top:0;}.ssrcss-1rmamhg-Grid >:nth-of-type(2),.ssrcss-1rmamhg-Grid >:nth-of-type(3){width:calc(25% - 6px);margin-top:0;}.ssrcss-1rmamhg-Grid >:nth-of-type(3n + 3){margin-right:0;}}@media all and (min-width: 56.25rem){.ssrcss-1rmamhg-Grid >*{height:auto;margin:16px 16px 0 0;width:calc(99.99% / 3 - (32px / 3));}.ssrcss-1rmamhg-Grid >:nth-of-type(1){width:calc(50% - 8px);}.ssrcss-1rmamhg-Grid >:nth-of-type(2),.ssrcss-1rmamhg-Grid >:nth-of-type(3){width:calc(25% - 12px);}}@supports (display: grid){.ssrcss-1rmamhg-Grid{display:grid;gap:8px;grid-template-columns:minmax(0, 1fr);grid-template-areas:'p1' 'p2' 'p3' 'p4' 'p5';}.ssrcss-1rmamhg-Grid >*{height:initial;margin:initial;width:initial;}.ssrcss-1rmamhg-Grid >:nth-of-type(1),.ssrcss-1rmamhg-Grid >:nth-of-type(2),.ssrcss-1rmamhg-Grid >:nth-of-type(3){width:initial;}.ssrcss-1rmamhg-Grid >:nth-of-type(3n + 1),.ssrcss-1rmamhg-Grid >:nth-of-type(3n + 3),.ssrcss-1rmamhg-Grid >:nth-of-type(2n + 1),.ssrcss-1rmamhg-Grid >:nth-of-type(2n + 2){margin:initial;}@media (min-width: 37.5rem){.ssrcss-1rmamhg-Grid{gap:16px;}}@media (min-width: 18.75rem){.ssrcss-1rmamhg-Grid{grid-template-columns:repeat(2, minmax(0, 1fr));grid-template-areas:'p1  p1' 'p2  p3' 'p4  p4' 'p5  p5';}}@media (min-width: 37.5rem){.ssrcss-1rmamhg-Grid{grid-template-columns:repeat(3, minmax(0, 1fr));grid-template-areas:'p1  p1  p2' 'p3  p4  p5';}}@media (min-width: 56.25rem){.ssrcss-1rmamhg-Grid{grid-template-columns:repeat(4, minmax(0, 1fr));grid-template-areas:'p1  p1  p2  p3' 'p1  p1  p4  p5';}}@media (min-width: 80rem){.ssrcss-1rmamhg-Grid{grid-template-columns:repeat(4, minmax(0, 1fr));grid-template-areas:'p1  p1  p2  p3' 'p1  p1  p4  p5';}}}.ssrcss-fcf6gd-Container{contain:content;padding:16px 0;box-sizing:border-box;margin:0 auto;max-width:63rem;}@media (min-width: 37.5rem){.ssrcss-fcf6gd-Container{padding:16px;}}@media (min-width: 80rem){.ssrcss-fcf6gd-Container{max-width:80rem;}}.ssrcss-ow0qo-StyledBackground{top:0;bottom:0;width:100%;position:absolute;-webkit-background-size:cover;background-size:cover;background-image:url('https://static.files.bbci.co.uk/core/website/assets/static/container-background-masks/message-banner-ambient.005755961d.jpg');mix-blend-mode:soft-light;}.ssrcss-oy2w6t-StyledContent{font-family:ReithSans,Helvetica,Arial,freesans,sans-serif;font-weight:400;font-feature-settings:'ss01' off;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;padding:24px 0 16px 0;}@media (min-width: 37.5rem){.ssrcss-oy2w6t-StyledContent{padding-top:16px;padding:24px 0;}}.ssrcss-13o7dl4-TextWra ...
#   min-width: 37.5rem){.ssrcss-de737q-Container{padding-bottom:24px;}}@media (min-width: 56.25rem){.ssrcss-de737q-Container{padding-bottom:16px;}}@media (
#     min-width: 37.5rem){html.no-js .ssrcss-de737q-Container{padding-bottom:24px;}}@media (min-width: 56.25rem){html.no-js .ssrcss-de737q-Container{padding-bottom:16px;}}@media (min-width: 56.25rem){.ssrcss-to0lb-GridWrapper{display:grid;grid-template-columns:minmax(0, 1fr) auto;grid-template-areas:'heading cta' 'promos promos';grid-template-rows:auto 1fr;-webkit-align-items:baseline;-webkit-box-align:baseline;-ms-flex-align:baseline;align-items:baseline;}}.ssrcss-1euuxgm-StyledHeadingWrapper{padding:16px 0;}@media (min-width: 56.25rem){.ssrcss-1euuxgm-StyledHeadingWrapper{grid-area:heading;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;}}@media (min-width: 56.25rem){.ssrcss-1wsw50m-SimpleCollectionsWrapper{grid-area:promos;}}.ssrcss-qe0dxm-Grid{position:relative;width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;margin:0;padding:0;list-style:none;}.ssrcss-qe0dxm-Grid >*{margin-top:8px;width:calc(100% - 4px);height:auto;}@media (min-width: 37.5rem){.ssrcss-qe0dxm-Grid >*{margin:8px 4px 0 4px;width:calc((99.99% / 4) - (8px));}}@media (min-width: 56.25rem){.ssrcss-qe0dxm-Grid >*{margin:16px 8px 0 8px;width:calc((99.99% / 4) - 16px);}}@media (min-width: 80rem){.ssrcss-qe0dxm-Grid >*{margin:16px 8px 0 8px;width:calc((99.99% / 4) - 16px);}}@supports (display: grid){.ssrcss-qe0dxm-Grid{display:grid;grid-gap:8px;gap:8px;grid-template-columns:minmax(0, 1fr);grid-template-areas:'p1' 'p2' 'p3' 'p4';}.ssrcss-qe0dxm-Grid >*{margin:initial;width:initial;height:initial;}.ssrcss-qe0dxm-Grid >:nth-child(1){grid-area:p1;}.ssrcss-qe0dxm-Grid >:nth-child(2){grid-area:p2;}.ssrcss-qe0dxm-Grid >:nth-child(3){grid-area:p3;}.ssrcss-qe0dxm-Grid >:nth-child(4){grid-area:p4;}.ssrcss-qe0dxm-Grid >:nth-child(5){grid-area:p5;}@media (min-width: 37.5rem){.ssrcss-qe0dxm-Grid{gap:16px;}}@media (min-width: 37.5rem){.ssrcss-qe0dxm-Grid{grid-template-columns:repeat(2, minmax(0, 1fr));grid-template-areas:'p1  p2' 'p3  p4';}}@media (min-width: 56.25rem){.ssrcss-qe0dxm-Grid{grid-template-columns:repeat(4, minmax(0, 1fr));grid-template-areas:'p1  p2  p3  p4';}}@media (min-width: 80rem){.ssrcss-qe0dxm-Grid{grid-template-columns:repeat(4, minmax(0, 1fr));grid-template-areas:'p1  p2  p3  p4';}}}.ssrcss-wguom3-UncontainedPromoWrapper{height:100%;box-sizing:border-box;padding-bottom:8px;}@media (min-width: 0rem) and (max-width: 24.99875rem){.ssrcss-wguom3-UncontainedPromoWrapper{border-top:false;padding-top:0;padding-bottom:0;}}@media (min-width: 25rem) and (max-width: 37.49875rem){.ssrcss-wguom3-UncontainedPromoWrapper{border-top:false;padding-top:0;padding-bottom:0;}}.ssrcss-8f58ma-HighImpactPromo{font-family:ReithSans,Helvetica,Arial,freesans,sans-serif;font-weight:400;font-feature-settings:'ss01' off;font-size:0.875rem;line-height:1.2857142857142858;position:relative;height:100%;background:#202224;outline:solid transparent;color:#F6F6F6;}.ssrcss-8f58ma-HighImpactPromo a:not(.e1plh41u1){z-index:2;position:relative;}@media (min-width: 0rem) and (max-width: 24.99875rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;position:relative;min-height:calc((50vw - 8px + 0.75rem) * 0.5625);}@media (min-width: 56.25rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints{min-height:calc((50vw - 16px + 1rem) * 0.5625);}}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30,.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{box-sizing:border-box;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30{position:relative;width:100%;-webkit-flex:0 0 calc(50% + 0.75rem);-ms-flex:0 0 calc(50% + 0.75rem);flex:0 0 calc(50% + 0.75rem);}@media (min-width: 56.25rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30{-webkit-flex:0 0 calc(50% + 1rem);-ms-flex:0 0 calc(50% + 1rem);flex:0 0 calc(50% + 1rem);} ...
#           to left,
#           color(from #202224 srgb r g b / 1) 0%,
#           color(from #202224 srgb r g b / 0.95) 4%,
#           color(from #202224 srgb r g b / 0) 50%
#         );}}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .etlorgc0{height:100%;padding-bottom:0;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30 img{position:absolute;height:100%;width:100%;object-fit:cover;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{-webkit-order:2;-ms-flex-order:2;order:2;z-index:2;width:50%;}@supports (color: color(from black srgb r g b / 1)){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{margin-left:calc(0.75rem * -1);}@media (min-width: 56.25rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{margin-left:calc((16px + 1rem) * -1);}}}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4 a:not(a:hover){color:#F6F6F6;}}@media (min-width: 25rem) and (max-width: 37.49875rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;position:relative;min-height:calc((50vw - 8px + 0.75rem) * 0.5625);}@media (min-width: 56.25rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints{min-height:calc((50vw - 16px + 1rem) * 0.5625);}}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30,.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{box-sizing:border-box;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30{position:relative;width:100%;-webkit-flex:0 0 calc(50% + 0.75rem);-ms-flex:0 0 calc(50% + 0.75rem);flex:0 0 calc(50% + 0.75rem);}@media (min-width: 56.25rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30{-webkit-flex:0 0 calc(50% + 1rem);-ms-flex:0 0 calc(50% + 1rem);flex:0 0 calc(50% + 1rem);}}@supports (color: color(from black srgb r g b / 1)){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30::before{content:'';position:absolute;right:0;top:0;height:100%;width:100%;z-index:1;background:linear-gradient(
#           to left,
#           color(from #202224 srgb r g b / 1) 0%,
#           color(from #202224 srgb r g b / 0.95) 4%,
#           color(from #202224 srgb r g b / 0) 50%
#         );}}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .etlorgc0{height:100%;padding-bottom:0;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30 img{position:absolute;height:100%;width:100%;object-fit:cover;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{-webkit-order:2;-ms-flex-order:2;order:2;z-index:2;width:50%;}@supports (color: color(from black srgb r g b / 1)){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{margin-left:calc(0.75rem * -1);}@media (min-width: 56.25rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{margin-left:calc((16px + 1rem) * -1);}}}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4 a:not(a:hover){color:#F6F6F6;}}@media (min-width: 37.5rem) and (max-width: 56.24875rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;height:100%;overflow:hidden;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30{width:calc(100% + (1.25rem / 9) * 16);-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;position:relative;-webkit-flex:none;-ms-flex:none;flex:none;}@media (min-width: 56.25rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30{width:calc(100% + (1.5rem / 9) * 16);}}@supports (color: color(from black srgb r g b / 1)){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30::before{content:'';position:absolute;right:0;top:0;height:100%;width:100%;z-index:1;background:linear-gradient(
#           to top,
#           color(from #202224 srgb r g b / 1) 0%,
#           color(from #202224 srgb r g b / 0.95) 0.5rem,
#           color(from #202224 srgb r g b / 0) 50%
#         );}}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .etlorgc0{position:initial;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30>picture{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30 img{object-fit:cover;width:100%;height:100%;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{z-index:2;-webkit-box-pack:justify;-webkit-justify-content:space-between;justify-content:space-between;-webkit-order:2;-ms-flex-order:2;order:2;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;}@supports (color: color(from black srgb r g b / 1)){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{margin-top:calc((1.25rem) * -1);}@media (min-width: 56.25rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{margin-top:calc((1.5rem) * -1);}}}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4 a:not(a:hover){color:#F6F6F6;}}@media (min-width: 56.25rem) and (max-width: 62.99875rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;height:100%;overflow:hidden;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30{width:calc(100% + (1.25rem / 9) * 16);-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;position:relative;-webkit-flex:none;-ms-flex:none;flex:none;}@media (min-width: 56.25rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30{width:calc(100% + (1.5rem / 9) * 16);}}@supports (color: color(from black srgb r g b / 1)){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30::before{content:'';position:absolute;right:0;top:0;height:100%;width:100%;z-index:1;background:linear-gradient(
#           to top,
#           color(from #202224 srgb r g b / 1) 0%,
#           color(from #202224 srgb r g b / 0.95) 0.5rem,
#           color(from #202224 srgb r g b / 0) 50%
#         );}}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .etlorgc0{position:initial;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30>picture{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30 img{object-fit:cover;width:100%;height:100%;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{z-index:2;-webkit-box-pack:justify;-webkit-justify-content:space-between;justify-content:space-between;-webkit-order:2;-ms-flex-order:2;order:2;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;}@supports (color: color(from black srgb r g b / 1)){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{margin-top:calc((1.25rem) * -1);}@media (min-width: 56.25rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{margin-top:calc((1.5rem) * -1);}}}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4 a:not(a:hover){color:#F6F6F6;}}@media (min-width: 63rem) and (max-width: 79.99875rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;height:100%;overflow:hidden;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30{width:calc(100% + (1.25rem / 9) * 16);-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;position:relative;-webkit-flex:none;-ms-flex:none;flex:none;}@media (min-width: 56.25rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30{width:calc(100% + (1.5rem / 9) * 16);}}@supports (color: color(from black srgb r g b / 1)){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30::before{content:'';position:absolute;right:0;top:0;height:100%;width:100%;z-index:1;background:linear-gradient(
#           to top,
#           color(from #202224 srgb r g b / 1) 0%,
#           color(from #202224 srgb r g b / 0.95) 0.5rem,
#           color(from #202224 srgb r g b / 0) 50%
#         );}}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .etlorgc0{position:initial;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30>picture{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30 img{object-fit:cover;width:100%;height:100%;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{z-index:2;-webkit-box-pack:justify;-webkit-justify-content:space-between;justify-content:space-between;-webkit-order:2;-ms-flex-order:2;order:2;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;}@supports (color: color(from black srgb r g b / 1)){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{margin-top:calc((1.25rem) * -1);}@media (min-width: 56.25rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{margin-top:calc((1.5rem) * -1);}}}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4 a:not(a:hover){color:#F6F6F6;}}@media (min-width: 80rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;height:100%;overflow:hidden;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30{width:calc(100% + (1.25rem / 9) * 16);-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;position:relative;-webkit-flex:none;-ms-flex:none;flex:none;}@media (min-width: 56.25rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30{width:calc(100% + (1.5rem / 9) * 16);}}@supports (color: color(from black srgb r g b / 1)){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30::before{content:'';position:absolute;right:0;top:0;height:100%;width:100%;z-index:1;background:linear-gradient(
#           to top,
#           color(from #202224 srgb r g b / 1) 0%,
#           color(from #202224 srgb r g b / 0.95) 0.5rem,
#           color(from #202224 srgb r g b / 0) 50%
#         );}}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .etlorgc0{position:initial;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30>picture{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .erpinv30 img{object-fit:cover;width:100%;height:100%;}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{z-index:2;-webkit-box-pack:justify;-webkit-justify-content:space-between;justify-content:space-between;-webkit-order:2;-ms-flex-order:2;order:2;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;}@supports (color: color(from black srgb r g b / 1)){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{margin-top:calc((1.25rem) * -1);}@media (min-width: 56.25rem){.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4{margin-top:calc((1.5rem) * -1);}}}.ssrcss-g78frt-PromoSwitchLayoutAtBreakpoints .e1plh41u4 a:not(a:hover){color:#F6F6F6;}}.ssrcss-1kn02it-PromoContent{box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;justify-content:space-between;word-wrap:break-word;overflow-wrap:break-word;padding:8px;}@media (min-width: 56.25rem){.ssrcss-1kn02it-PromoContent{padding:12px 16px;}}.ssrcss-1kn02it-PromoContent >*{-webkit-flex:none;-ms-flex:none;flex:none;}.ssrcss-1kn02it-PromoContent >*:not([hidden]):not(style):not(.visually-hidden)~*:not([hidden]):not(style):not(.visually-hidden){margin-top:16px;}.ssrcss-16ny86l-PromoLink{display:block;font-size:1rem;line-height:1.25;color:#F6F6F6;}@media (min-width: 37.5rem){.ssrcss-16ny86l-PromoLink{font-size:1.125rem;line-height:1.222222222222222;}}.ssrcss-16ny86l-PromoLink:any-link{-webkit-text-decoration:none;text-decoration:none;color:#F6F6F6;}.ssrcss-16ny86l-PromoLink:any-link:hover,.ssrcss-16ny86l-PromoLink:any-link:focus,.ssrcss-16ny86l-PromoLink:any-link:active{-webkit-text-decoration:underline;text-decoration:underline;}.ssrcss-16ny86l-PromoLink::after{content:'';position:absolute;top:0;right:0;bottom:0;left:0;z-index:2;}.ssrcss-sc0di0-MetadataStripContainer{font-family:ReithSans,Helvetica,Arial,freesans,sans-serif;font-weight:400;font-feature-settings:'ss01' off;font-size:0.8125rem;line-height:1.2307692307692308;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;max-width:100%;-webkit-box-flex-wrap:wrap-reverse;-webkit-flex-wrap:wrap-reverse;-ms-flex-wrap:wrap-reverse;flex-wrap:wrap-reverse;margin-top:-4px;color:#B0B2B4;overflow:hidden;list-style:none;padding:0;line-height:1.5rem;}.ssrcss-doaw5h-PromoImageContainer{overflow:hidden;}.ssrcss-d2wl7g-Placeholder{display:block;position:relative;background-color:#202224;padding-bottom:56.25%;}.ssrcss-sp3f6e-PromoFooterLayout{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:4px;-webkit-align-items:end;-webkit-box-align:end;-ms-flex-align:end;align-items:end;}.ssrcss-sp3f6e-PromoFooterLayout >*{-webkit-flex:1;-ms-flex:1;flex:1;}.ssrcss-sp3f6e-PromoFooterLayout >.exn3ah92{-webkit-flex:none;-ms-flex:none;flex:none;}.ssrcss-eyl4yh-MetadataStripWrapper{margin-bottom:8px;min-width:0;}.ssrcss-184u64p-PromoButtonSlot{position:relative;z-index:3;margin-left:auto;}.ssrcss-1eii3hh-ButtonWrapper{width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;}html.no-js .ssrcss-1eii3hh-ButtonWrapper{display:none;}.ssrcss-vhi7dd-ContentsWrapper{display:grid;width:100%;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;}.ssrcss-1vyztud-ButtonStyles{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;a ...
#   min-width: 37.5rem){.ssrcss-dvppw8-Container{padding-bottom:24px;-webkit-background-size:cover;background-size:cover;background-image:url(https://ichef.bbci.co.uk/ace/standard/900/cpsprodpb/0cf7/live/17339b60-c183-11f0-8456-eff94716b162.png);}}@media (min-width: 56.25rem){.ssrcss-dvppw8-Container{padding-bottom:16px;-webkit-background-size:cover;background-size:cover;background-image:url(https://ichef.bbci.co.uk/ace/standard/1008/cpsprodpb/0cf7/live/17339b60-c183-11f0-8456-eff94716b162.png);}}@media (min-width: 63rem){.ssrcss-dvppw8-Container{-webkit-background-size:cover;background-size:cover;background-image:url(https://ichef.bbci.co.uk/ace/standard/1280/cpsprodpb/0cf7/live/17339b60-c183-11f0-8456-eff94716b162.png);}}html.no-js .ssrcss-dvppw8-Container{-webkit-background-size:cover;background-size:cover;background-image:url(https://ichef.bbci.co.uk/ace/standard/1280/cpsprodpb/0cf7/live/17339b60-c183-11f0-8456-eff94716b162.png);}@media (
#     min-width: 37.5rem){html.no-js .ssrcss-dvppw8-Container{padding-bottom:24px;-webkit-background-size:cover;background-size:cover;background-image:url(https://ichef.bbci.co.uk/ace/standard/900/cpsprodpb/0cf7/live/17339b60-c183-11f0-8456-eff94716b162.png);}}@media (min-width: 56.25rem){html.no-js .ssrcss-dvppw8-Container{padding-bottom:16px;-webkit-background-size:cover;background-size:cover;background-image:url(https://ichef.bbci.co.uk/ace/standard/1008/cpsprodpb/0cf7/live/17339b60-c183-11f0-8456-eff94716b162.png);}}@media (min-width: 63rem){html.no-js .ssrcss-dvppw8-Container{-webkit-background-size:cover;background-size:cover;background-image:url(https://ichef.bbci.co.uk/ace/standard/1280/cpsprodpb/0cf7/live/17339b60-c183-11f0-8456-eff94716b162.png);}}.ssrcss-mq1cq4-Heading{font-family:ReithSans,Helvetica,Arial,freesans,sans-serif;font-weight:700;font-feature-settings:'ss01' off;font-size:1.25rem;line-height:1.2;margin:0;color:#F6F6F6;}@media (min-width: 37.5rem){.ssrcss-mq1cq4-Heading{font-size:1.5rem;line-height:1.1666666666666667;}}.ssrcss-mq1cq4-Heading:focus{outline-style:none;}.ssrcss-mq1cq4-Heading:focus-visible{outline-style:auto;}.ssrcss-1k3ynit-IndexPromo{font-family:ReithSans,Helvetica,Arial,freesans,sans-serif;font-weight:400;font-feature-settings:'ss01' off;font-size:0.875rem;line-height:1.2857142857142858;position:relative;height:100%;background:#202224;outline:solid transparent;color:#F6F6F6;}.ssrcss-1k3ynit-IndexPromo a:not(.ebld8cw3){z-index:2;position:relative;}.ssrcss-tk1hp3-PromoLayout{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.ssrcss-tk1hp3-PromoLayout .ebld8cw5{z-index:2;-webkit-order:2;-ms-flex-order:2;order:2;}.ssrcss-tk1hp3-PromoLayout .e1gprzbq1{position:relative;-webkit-flex:none;-ms-flex:none;flex:none;}.ssrcss-tk1hp3-PromoLayout .e1gprzbq1:before{content:'';position:absolute;right:0;top:0;height:100%;width:100%;z-index:1;}.ssrcss-tk1hp3-PromoLayout .etlorgc0{position:initial;}.ssrcss-tk1hp3-PromoLayout .e1gprzbq1>picture{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;}.ssrcss-tk1hp3-PromoLayout .e1gprzbq1 img{object-fit:contain;width:100%;height:100%;aspect-ratio:16/9;}.ssrcss-tk1hp3-PromoLayout .ebld8cw6{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}.ssrcss-tk1hp3-PromoLayout .ebld8cw5{-webkit-box-pack:justify;-webkit-justify-content:space-between;justify-content:space-between;-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;}.ssrcss-tk1hp3-PromoLayout .ebld8cw5 a:not(a:hover){color:#F6F6F6;}.ssrcss-tk1hp3-PromoLayout .ebld8cw0{text-align:center;margin-bottom:16px;margin-top:-4px;}.ssrcss-1l4e0tu-PromoContentContainer{-webkit-order:2;-ms-flex-order:2;order:2;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-box-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex:1;-ms-flex:1;flex:1;width:100%;}.ssrcss-t98und-PromoContent{box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;justify-content:space-between;word-wrap:break-word;overflow-wrap:break-word;padding:8px;padding-top:12px;max-width:100%;}@media (min-width: 56.25rem){.ssrcss-t98und-PromoContent{padding:12px;}}.ssrcss-t98und-PromoContent >*{-webkit-flex:none;-ms-flex:none;flex:none;}.ssrcss-6xf111-PromoLink:link{-webkit-text-decoration:none;text-decoration:none;color:#F6F6F6;}.ssrcss-6xf111-PromoLink:hover,.ssrcss-6xf111-PromoL ...
#     The Night Manager</div><div data-testid="panelcontent">Latest updates from your followed topics will now appear in a collection on the<!-- --> <a href="https://www.bbc.co.uk/" class="ssrcss-16xv11k-StyledLink e20acq30">BBC homepage</a>.</div></div></div></div></div></div></div></div></div></div><div class="ssrcss-z60stg-PromoImageContainer en81kx34"><div class="ssrcss-17h6w1t-PromoImageContainerInner en81kx32"><div class="ssrcss-fec6qv-ImageWrapper en81kx33"><span class="ssrcss-5zsoxt-Placeholder etlorgc0"><picture><source srcSet="https://ichef.bbci.co.uk/ace/standard/960/cpsprodpb/5c63/live/f280e8f0-bee8-11f0-ae46-bd64331f0fd4.jpg.webp 960w" type="image/webp" sizes="960px"/><img alt="The Night Manager: Official Trailer" loading="lazy" sizes="960px" src="https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/5c63/live/f280e8f0-bee8-11f0-ae46-bd64331f0fd4.jpg" srcSet="https://ichef.bbci.co.uk/ace/standard/960/cpsprodpb/5c63/live/f280e8f0-bee8-11f0-ae46-bd64331f0fd4.jpg 960w" width="240" height="135" fetchPriority="auto" class="ssrcss-11yxrdo-Image edrdn950"/></picture></span></div></div></div></div></div></div></li><li class="ssrcss-1dr5icq-ListItem e1gp961v0"><div class="ssrcss-jztzkt-UncontainedPromoWrapper eqfxz1e4"><div data-testid="promo" type="brand" class="ssrcss-f2apad-Promo e1vyq2e80"><div class="ssrcss-134rp3c-PromoSwitchLayoutAtBreakpoints et5qctl0"><div class="ssrcss-k49uhy-PromoContent exn3ah912"><div spacing="2" class="ssrcss-espw6b-Stack e1y4nx260"><h3><a href="/sounds/play/m002n36k?at_mid=l08qSv2Fcz&amp;at_campaign=Ready_to_Talk_with_Emma_Barnett_Chris_McCausland&amp;at_medium=display_ad&amp;at_campaign_type=owned&amp;at_nation=NET&amp;at_audience_id=SS&amp;at_product=sounds&amp;at_brand=p0mdcpkb&amp;at_ptr_name=bbc&amp;at_ptr_type=media&amp;at_format=image&amp;at_objective=consumption&amp;at_link_title=Ready_to_Talk_with_Emma_Barnett_Chris_McCausland&amp;at_bbc_team=BBC" class="ssrcss-5wtq5v-PromoLink exn3ah94"><span role="text"><p class="ssrcss-1sen9vx-PromoHeadline exn3ah99"><span aria-hidden="false">Chris McCausland joins Emma to discuss dancing blind on TV</span></p></span></a></h3></div><div spacing="4" class="ssrcss-1j1rzn0-Stack e1y4nx260"><div class="ssrcss-sp3f6e-PromoFooterLayout exn3ah91"><div class="ssrcss-eyl4yh-MetadataStripWrapper exn3ah90"><div><ul role="list" class="ssrcss-1q1gjvm-MetadataStripContainer eh44mf03"><li role="listitem" class="ssrcss-1dqo2s-MetadataStripItem eh44mf01"><div class="visually-hidden ssrcss-1f39n02-VisuallyHidden e16en2lz0">Attribution</div><div class="ssrcss-m5j4pi-MetadataContent eh44mf00"><span class="ssrcss-1pvwv4b-MetadataSnippet e4wm5bw3"><span type="attribution" class="ssrcss-61mhsj-MetadataText e4wm5bw1"><span data-testid="service-identifiers:sounds" class="ssrcss-ar8sc2-IconContainer e4wm5bw0"><svg viewBox="0 0 348 336" width="1em" height="1em" class="ssrcss-xi5oyi-StyledIcon e161cein1" focusable="false" aria-hidden="true"><g><path fill="#A13104" d="M46,216H2c-0.6,0-1.1-0.2-1.4-0.6S0,214.6,0,214v-92c0-0.6,0.2-1.1,0.6-1.4S1.4,120,2,120h44 c0.6,0,1.1,0.2,1.4,0.6s0.6,0.9,0.6,1.4v92c0,0.6-0.2,1.1-0.6,1.4S46.6,216,46,216z"></path><path fill="#D24712" d="M154,288H74c-0.6,0-1.1-0.2-1.4-0.6S72,286.6,72,286V50c0-0.6,0.2-1.1,0.6-1.4S73.4,48,74,48h80 c0.6,0,1.1,0.2,1.4,0.6s0.6,0.9,0.6,1.4v236c0,0.6-0.2,1.1-0.6,1.4S154.6,288,154,288z"></path><path fill="#FA6400" d="M346,336H182c-0.6,0-1.1-0.2-1.4-0.6s-0.6-0.9-0.6-1.4V2c0-0.6,0.2-1.1,0.6-1.4S181.4,0,182,0h164 c0.6,0,1.1,0.2,1.4,0.6S348,1.4,348,2v332c0,0.6-0.2,1.1-0.6,1.4S346.6,336,346,336z"></path></g></svg></span>Sounds</span></span></div></li></ul></div></div><div class="ssrcss-184u64p-PromoButtonSlot exn3ah92"><div><div data-testid="information-panel" class="ssrcss-5tewi8-StyledInformationPanel eu74mg85"><div><div class="ssrcss-1eii3hh-ButtonWrapper e19pe5mb4"><button width="content-length" type="button" aria-labelledby="_R_2lajail5a75a_" aria-expanded="false" data-testid="uas-button" class="ssrcss-14xswcd-Button eoocus ...
#     Ready to Talk with Emma Barnett</div><div data-testid="panelcontent">Latest updates from your followed topics will now appear in a collection on the<!-- --> <a href="https://www.bbc.co.uk/" class="ssrcss-16xv11k-StyledLink e20acq30">BBC homepage</a>.</div></div></div></div></div></div></div></div></div></div><div class="ssrcss-z60stg-PromoImageContainer en81kx34"><div class="ssrcss-17h6w1t-PromoImageContainerInner en81kx32"><div class="ssrcss-fec6qv-ImageWrapper en81kx33"><span class="ssrcss-5zsoxt-Placeholder etlorgc0"><picture><source srcSet="https://ichef.bbci.co.uk/ace/standard/960/cpsprodpb/5069/live/0fb1d4c0-c137-11f0-8669-5560f5c90fbe.jpg.webp 960w" type="image/webp" sizes="960px"/><img alt="Ready to Talk with Emma Barnett" loading="lazy" sizes="960px" src="https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/5069/live/0fb1d4c0-c137-11f0-8669-5560f5c90fbe.jpg" srcSet="https://ichef.bbci.co.uk/ace/standard/960/cpsprodpb/5069/live/0fb1d4c0-c137-11f0-8669-5560f5c90fbe.jpg 960w" width="240" height="135" fetchPriority="auto" class="ssrcss-11yxrdo-Image edrdn950"/></picture></span></div></div></div></div></div></div></li><li class="ssrcss-1r7nvnf-ListItem e1gp961v0"><div class="ssrcss-jztzkt-UncontainedPromoWrapper eqfxz1e4"><div data-testid="promo" type="brand" class="ssrcss-f2apad-Promo e1vyq2e80"><div class="ssrcss-134rp3c-PromoSwitchLayoutAtBreakpoints et5qctl0"><div class="ssrcss-k49uhy-PromoContent exn3ah912"><div spacing="2" class="ssrcss-espw6b-Stack e1y4nx260"><h3><a href="/iplayer/episodes/m002hzfm/watch/p0mf42py?at_mid=fVIsteMxng&amp;at_campaign=BBC_Trailers_Prisoner_951&amp;at_medium=display_ad&amp;at_campaign_type=owned&amp;at_nation=NET&amp;at_audience_id=SS&amp;at_product=iplayer&amp;at_brand=m002hzfm&amp;at_ptr_name=bbc&amp;at_ptr_type=media&amp;at_format=image&amp;at_objective=consumption&amp;at_link_title=BBC_Trailers_Prisoner_951&amp;at_bbc_team=BBC" class="ssrcss-5wtq5v-PromoLink exn3ah94"><span role="text"><p class="ssrcss-1sen9vx-PromoHeadline exn3ah99"><span aria-hidden="false">Drama based on Nazanin Zaghari-Ratcliffe&#x27;s fight for justice</span></p></span></a></h3></div><div spacing="4" class="ssrcss-1j1rzn0-Stack e1y4nx260"><div class="ssrcss-sp3f6e-PromoFooterLayout exn3ah91"><div class="ssrcss-eyl4yh-MetadataStripWrapper exn3ah90"><div><ul role="list" class="ssrcss-1q1gjvm-MetadataStripContainer eh44mf03"><li role="listitem" class="ssrcss-1dqo2s-MetadataStripItem eh44mf01"><div class="visually-hidden ssrcss-1f39n02-VisuallyHidden e16en2lz0">Attribution</div><div class="ssrcss-m5j4pi-MetadataContent eh44mf00"><span class="ssrcss-1pvwv4b-MetadataSnippet e4wm5bw3"><span type="attribution" class="ssrcss-61mhsj-MetadataText e4wm5bw1"><span data-testid="service-identifiers:iplayer" class="ssrcss-ar8sc2-IconContainer e4wm5bw0"><svg viewBox="0 0 294 339" width="1em" height="1em" class="ssrcss-xi5oyi-StyledIcon e161cein1" focusable="false" aria-hidden="true"><g><path fill="#DC2878" d="M69.9,271.4H2c-0.5,0-1-0.2-1.4-0.6C0.2,270.5,0,270,0,269.4V69.6c0-0.6,0.2-1.1,0.6-1.4s0.9-0.6,1.4-0.6h67.9 c0.5,0,1,0.2,1.4,0.6c0.4,0.4,0.6,0.9,0.6,1.4v199.8c0,0.6-0.2,1.1-0.6,1.4C71,271.2,70.5,271.4,69.9,271.4z"></path><g><path fill="#FF4C98" d="M259.8,161.7l34-58.8c0.3-0.5,0.3-1,0.2-1.5c-0.1-0.5-0.5-0.9-0.9-1.2L120,0.3c-0.5-0.3-1-0.3-1.5-0.2 c-0.5,0.1-0.9,0.5-1.2,0.9l-34,58.8c-0.3,0.5-0.3,1-0.2,1.5c0.1,0.5,0.5,0.9,0.9,1.2l173,99.9c0.5,0.3,1,0.3,1.5,0.2 C259.1,162.5,259.5,162.2,259.8,161.7z"></path><path fill="#AF0D5B" d="M259.8,177.3l34,58.8c0.3,0.5,0.3,1,0.2,1.5c-0.1,0.5-0.5,0.9-0.9,1.2l-173,99.9c-0.5,0.3-1,0.3-1.5,0.2 c-0.5-0.1-0.9-0.5-1.2-0.9l-34-58.8c-0.3-0.5-0.3-1-0.2-1.5c0.1-0.5,0.5-0.9,0.9-1.2l173-99.9c0.5-0.3,1-0.3,1.5-0.2 C259.1,176.5,259.5,176.8,259.8,177.3z"></path></g></g></svg></span>iPlayer</span></span></div></li></ul></div></div><div class="ssrcss-184u64p-PromoButtonSlot exn3ah92"><div><div data-testid="information-panel" class="ssrcss-5tewi8-StyledInformationPanel eu74mg85"><div><div class="ssrcss-1eii3 ...
# ...
#     Mr Burton</div><div data-testid="panelcontent">Latest updates from your followed topics will now appear in a collection on the<!-- --> <a href="https://www.bbc.co.uk/" class="ssrcss-16xv11k-StyledLink e20acq30">BBC homepage</a>.</div></div></div></div></div></div></div></div></div></div><div class="ssrcss-z60stg-PromoImageContainer en81kx34"><div class="ssrcss-17h6w1t-PromoImageContainerInner en81kx32"><div class="ssrcss-fec6qv-ImageWrapper en81kx33"><span class="ssrcss-5zsoxt-Placeholder etlorgc0"><picture><source srcSet="https://ichef.bbci.co.uk/ace/standard/960/cpsprodpb/dc04/live/25cfa4d0-b976-11f0-b2a1-6f537f66f9aa.jpg.webp 960w" type="image/webp" sizes="960px"/><img alt="Mr. Burton" loading="lazy" sizes="960px" src="https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/dc04/live/25cfa4d0-b976-11f0-b2a1-6f537f66f9aa.jpg" srcSet="https://ichef.bbci.co.uk/ace/standard/960/cpsprodpb/dc04/live/25cfa4d0-b976-11f0-b2a1-6f537f66f9aa.jpg 960w" width="240" height="135" fetchPriority="auto" class="ssrcss-11yxrdo-Image edrdn950"/></picture></span></div></div></div></div></div></div></li><li class="ssrcss-vmhflp-ListItem e1gp961v0"><div class="ssrcss-ns41cv-UncontainedPromoWrapper eqfxz1e4"><div data-testid="promo" type="brand" class="ssrcss-f2apad-Promo e1vyq2e80"><div class="ssrcss-186fu1r-PromoSwitchLayoutAtBreakpoints et5qctl0"><div class="ssrcss-k49uhy-PromoContent exn3ah912"><div spacing="2" class="ssrcss-espw6b-Stack e1y4nx260"><h3><a href="/sounds/play/p0mg3g7m?at_mid=8exQGJoCj4&amp;at_campaign=Complex_with_Kimberley_Wilson_Are_you_too_empathetic&amp;at_medium=display_ad&amp;at_campaign_type=owned&amp;at_nation=NET&amp;at_audience_id=SS&amp;at_product=sounds&amp;at_brand=p0mcyd0k&amp;at_ptr_name=bbc&amp;at_ptr_type=media&amp;at_format=image&amp;at_objective=consumption&amp;at_link_title=Complex_with_Kimberley_Wilson_Are_you_too_empathetic&amp;at_bbc_team=BBC" class="ssrcss-5wtq5v-PromoLink exn3ah94"><span role="text"><p class="ssrcss-1sen9vx-PromoHeadline exn3ah99"><span aria-hidden="false">What&#x27;s the right amount of empathy?</span></p></span></a></h3></div><div spacing="4" class="ssrcss-1j1rzn0-Stack e1y4nx260"><div class="ssrcss-sp3f6e-PromoFooterLayout exn3ah91"><div class="ssrcss-eyl4yh-MetadataStripWrapper exn3ah90"><div><ul role="list" class="ssrcss-1q1gjvm-MetadataStripContainer eh44mf03"><li role="listitem" class="ssrcss-1dqo2s-MetadataStripItem eh44mf01"><div class="visually-hidden ssrcss-1f39n02-VisuallyHidden e16en2lz0">Attribution</div><div class="ssrcss-m5j4pi-MetadataContent eh44mf00"><span class="ssrcss-1pvwv4b-MetadataSnippet e4wm5bw3"><span type="attribution" class="ssrcss-61mhsj-MetadataText e4wm5bw1"><span data-testid="service-identifiers:sounds" class="ssrcss-ar8sc2-IconContainer e4wm5bw0"><svg viewBox="0 0 348 336" width="1em" height="1em" class="ssrcss-xi5oyi-StyledIcon e161cein1" focusable="false" aria-hidden="true"><g><path fill="#A13104" d="M46,216H2c-0.6,0-1.1-0.2-1.4-0.6S0,214.6,0,214v-92c0-0.6,0.2-1.1,0.6-1.4S1.4,120,2,120h44 c0.6,0,1.1,0.2,1.4,0.6s0.6,0.9,0.6,1.4v92c0,0.6-0.2,1.1-0.6,1.4S46.6,216,46,216z"></path><path fill="#D24712" d="M154,288H74c-0.6,0-1.1-0.2-1.4-0.6S72,286.6,72,286V50c0-0.6,0.2-1.1,0.6-1.4S73.4,48,74,48h80 c0.6,0,1.1,0.2,1.4,0.6s0.6,0.9,0.6,1.4v236c0,0.6-0.2,1.1-0.6,1.4S154.6,288,154,288z"></path><path fill="#FA6400" d="M346,336H182c-0.6,0-1.1-0.2-1.4-0.6s-0.6-0.9-0.6-1.4V2c0-0.6,0.2-1.1,0.6-1.4S181.4,0,182,0h164 c0.6,0,1.1,0.2,1.4,0.6S348,1.4,348,2v332c0,0.6-0.2,1.1-0.6,1.4S346.6,336,346,336z"></path></g></svg></span>Sounds</span></span></div></li></ul></div></div><div class="ssrcss-184u64p-PromoButtonSlot exn3ah92"><div><div data-testid="information-panel" class="ssrcss-5tewi8-StyledInformationPanel eu74mg85"><div><div class="ssrcss-1eii3hh-ButtonWrapper e19pe5mb4"><button width="content-length" type="button" aria-labelledby="_R_2lajaml5a75a_" aria-expanded="false" data-testid="uas-button" class="ssrcss-14xswcd-Button eoocusk1"><div class="ssrcss-vhi7dd-ContentsWrappe ...
#     Complex with Kimberley Wilson</div><div data-testid="panelcontent">Latest updates from your followed topics will now appear in a collection on the<!-- --> <a href="https://www.bbc.co.uk/" class="ssrcss-16xv11k-StyledLink e20acq30">BBC homepage</a>.</div></div></div></div></div></div></div></div></div></div><div class="ssrcss-z60stg-PromoImageContainer en81kx34"><div class="ssrcss-17h6w1t-PromoImageContainerInner en81kx32"><div class="ssrcss-fec6qv-ImageWrapper en81kx33"><span class="ssrcss-5zsoxt-Placeholder etlorgc0"><picture><source srcSet="https://ichef.bbci.co.uk/ace/standard/960/cpsprodpb/69ca/live/7abdc450-c140-11f0-8456-eff94716b162.jpg.webp 960w" type="image/webp" sizes="960px"/><img alt="Complex with Kimberley Wilson" loading="lazy" sizes="960px" src="https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/69ca/live/7abdc450-c140-11f0-8456-eff94716b162.jpg" srcSet="https://ichef.bbci.co.uk/ace/standard/960/cpsprodpb/69ca/live/7abdc450-c140-11f0-8456-eff94716b162.jpg 960w" width="240" height="135" fetchPriority="auto" class="ssrcss-11yxrdo-Image edrdn950"/></picture></span></div></div></div></div></div></div></li><li class="ssrcss-8k5g2t-ListItem e1gp961v0"><div class="ssrcss-ns41cv-UncontainedPromoWrapper eqfxz1e4"><div data-testid="promo" type="video" class="ssrcss-f2apad-Promo e1vyq2e80"><div class="ssrcss-186fu1r-PromoSwitchLayoutAtBreakpoints et5qctl0"><div class="ssrcss-k49uhy-PromoContent exn3ah912"><div spacing="2" class="ssrcss-espw6b-Stack e1y4nx260"><h3><a href="/iplayer/episode/b007cdz8?at_mid=2P393jit57&amp;at_campaign=Bridget_Joness_Diary&amp;at_medium=display_ad&amp;at_campaign_type=owned&amp;at_nation=NET&amp;at_audience_id=SS&amp;at_product=iplayer&amp;at_brand=b007cdz8&amp;at_ptr_name=bbc&amp;at_ptr_type=media&amp;at_format=image&amp;at_objective=consumption&amp;at_link_title=Bridget_Joness_Diary&amp;at_bbc_team=BBC" class="ssrcss-5wtq5v-PromoLink exn3ah94"><span role="text"><p class="ssrcss-1sen9vx-PromoHeadline exn3ah99"><span aria-hidden="false">RenÃ©e Zellweger stars as the iconic Bridget Jones</span></p></span></a></h3></div><div spacing="4" class="ssrcss-1j1rzn0-Stack e1y4nx260"><div class="ssrcss-sp3f6e-PromoFooterLayout exn3ah91"><div class="ssrcss-eyl4yh-MetadataStripWrapper exn3ah90"><div><ul role="list" class="ssrcss-1q1gjvm-MetadataStripContainer eh44mf03"><li role="listitem" class="ssrcss-1dqo2s-MetadataStripItem eh44mf01"><div class="visually-hidden ssrcss-1f39n02-VisuallyHidden e16en2lz0">Attribution</div><div class="ssrcss-m5j4pi-MetadataContent eh44mf00"><span class="ssrcss-1pvwv4b-MetadataSnippet e4wm5bw3"><span type="attribution" class="ssrcss-61mhsj-MetadataText e4wm5bw1"><span data-testid="service-identifiers:iplayer" class="ssrcss-ar8sc2-IconContainer e4wm5bw0"><svg viewBox="0 0 294 339" width="1em" height="1em" class="ssrcss-xi5oyi-StyledIcon e161cein1" focusable="false" aria-hidden="true"><g><path fill="#DC2878" d="M69.9,271.4H2c-0.5,0-1-0.2-1.4-0.6C0.2,270.5,0,270,0,269.4V69.6c0-0.6,0.2-1.1,0.6-1.4s0.9-0.6,1.4-0.6h67.9 c0.5,0,1,0.2,1.4,0.6c0.4,0.4,0.6,0.9,0.6,1.4v199.8c0,0.6-0.2,1.1-0.6,1.4C71,271.2,70.5,271.4,69.9,271.4z"></path><g><path fill="#FF4C98" d="M259.8,161.7l34-58.8c0.3-0.5,0.3-1,0.2-1.5c-0.1-0.5-0.5-0.9-0.9-1.2L120,0.3c-0.5-0.3-1-0.3-1.5-0.2 c-0.5,0.1-0.9,0.5-1.2,0.9l-34,58.8c-0.3,0.5-0.3,1-0.2,1.5c0.1,0.5,0.5,0.9,0.9,1.2l173,99.9c0.5,0.3,1,0.3,1.5,0.2 C259.1,162.5,259.5,162.2,259.8,161.7z"></path><path fill="#AF0D5B" d="M259.8,177.3l34,58.8c0.3,0.5,0.3,1,0.2,1.5c-0.1,0.5-0.5,0.9-0.9,1.2l-173,99.9c-0.5,0.3-1,0.3-1.5,0.2 c-0.5-0.1-0.9-0.5-1.2-0.9l-34-58.8c-0.3-0.5-0.3-1-0.2-1.5c0.1-0.5,0.5-0.9,0.9-1.2l173-99.9c0.5-0.3,1-0.3,1.5-0.2 C259.1,176.5,259.5,176.8,259.8,177.3z"></path></g></g></svg></span>iPlayer</span></span></div></li><div class="ssrcss-13nu8ri-GroupChildrenForWrapping eh44mf02"><li role="listitem" class="ssrcss-1dqo2s-MetadataStripItem eh44mf01"><div class="ssrcss-m5j4pi-MetadataContent eh44mf00"><span class="ssrcss-1pvwv4b-MetadataSnippet e4wm5bw3"><spa ...
#     Bridget Jones&#x27;s Diary</div><div data-testid="panelcontent">Latest updates from your followed topics will now appear in a collection on the<!-- --> <a href="https://www.bbc.co.uk/" class="ssrcss-16xv11k-StyledLink e20acq30">BBC homepage</a>.</div></div></div></div></div></div></div></div></div></div><div class="ssrcss-z60stg-PromoImageContainer en81kx34"><div class="ssrcss-17h6w1t-PromoImageContainerInner en81kx32"><div class="ssrcss-fec6qv-ImageWrapper en81kx33"><span class="ssrcss-5zsoxt-Placeholder etlorgc0"><picture><source srcSet="https://ichef.bbci.co.uk/ace/standard/960/cpsprodpb/de6e/live/47892a90-c0e9-11f0-ae46-bd64331f0fd4.jpg.webp 960w" type="image/webp" sizes="960px"/><img alt="Bridget Jones&#x27;s Diary" loading="lazy" sizes="960px" src="https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/de6e/live/47892a90-c0e9-11f0-ae46-bd64331f0fd4.jpg" srcSet="https://ichef.bbci.co.uk/ace/standard/960/cpsprodpb/de6e/live/47892a90-c0e9-11f0-ae46-bd64331f0fd4.jpg 960w" width="240" height="135" fetchPriority="auto" class="ssrcss-11yxrdo-Image edrdn950"/></picture></span></div></div></div></div></div></div></li></ul></div></div></div></div></div><div class="ssrcss-11vwucc-Container eqfxz1e6"><div class="ssrcss-4y0s1t-Wrap e42f8511"><div class="ssrcss-1nkp2z8-GridWrapper eqfxz1e3"><div class="ssrcss-mi7xqm-StyledHeadingLinkWrapper eqfxz1e8"><div spacing="2" class="ssrcss-cegw7a-Container evj0f8o0"><div class="ssrcss-1dnbtdo-HeadingContainer evj0f8o2"><h2 type="normal" class="ssrcss-ad2rmd-Heading e10rt3ze0"><a href="/sport" class="ssrcss-s25aj-StyledLink evj0f8o4">Sport<span class="ssrcss-1np6um0-IconContainer evj0f8o5"><svg viewBox="0 0 32 32" width="1em" height="1em" class="ssrcss-xi5oyi-StyledIcon e161cein1" focusable="false" aria-hidden="true"><path d="M21.6 14.3 5.5 31h6.4l14.6-15L11.9 1H5.5l16.1 16.7z"></path></svg></span></a></h2></div><div class="ssrcss-rcw297-ButtonsContainer evj0f8o1"></div></div></div><div class="ssrcss-1fyr2t1-HierarchicalCollectionsWrapper eqfxz1e2"><ul role="list" class="ssrcss-4k5ad1-Grid e12imr580"><li class="ssrcss-rs7w2i-ListItem e1gp961v0"><div class="ssrcss-jztzkt-UncontainedPromoWrapper eqfxz1e4"><div data-testid="promo" type="article" class="ssrcss-f2apad-Promo e1vyq2e80"><div class="ssrcss-134rp3c-PromoSwitchLayoutAtBreakpoints et5qctl0"><div class="ssrcss-k49uhy-PromoContent exn3ah912"><div spacing="2" class="ssrcss-espw6b-Stack e1y4nx260"><h3><a href="/sport/boxing/articles/cwyprrlww9do" class="ssrcss-gvf9zo-PromoLink exn3ah94"><span role="text"><p class="ssrcss-1sen9vx-PromoHeadline exn3ah99"><span aria-hidden="false">Joshua to fight YouTube star Paul in December</span></p></span></a></h3><p class="ssrcss-1q0x1qg-Paragraph e1jhz7w10">YouTuber Jake Paul will fight ex-world heavyweight champion Anthony Joshua in a professional bout in December. </p></div><div spacing="4" class="ssrcss-1j1rzn0-Stack e1y4nx260"><div><ul role="list" class="ssrcss-1q1gjvm-MetadataStripContainer eh44mf03"><li role="listitem" class="ssrcss-1dqo2s-MetadataStripItem eh44mf01"><div class="visually-hidden ssrcss-1f39n02-VisuallyHidden e16en2lz0">Attribution</div><div class="ssrcss-m5j4pi-MetadataContent eh44mf00"><span class="ssrcss-1pvwv4b-MetadataSnippet e4wm5bw3"><a href="/sport/boxing" class="ssrcss-11oiv5v-MetadataLink e4wm5bw2"><span type="attribution" class="ssrcss-61mhsj-MetadataText e4wm5bw1"><span data-testid="service-identifiers:sport" class="ssrcss-ar8sc2-IconContainer e4wm5bw0"><svg viewBox="0 0 336 336" width="1em" height="1em" class="ssrcss-xi5oyi-StyledIcon e161cein1" focusable="false" aria-hidden="true"><g><path fill="#FFD230" d="M2,96h332c0.6,0,1.1-0.2,1.4-0.6s0.6-0.9,0.6-1.4V2c0-0.6-0.2-1.1-0.6-1.4S334.6,0,334,0H2 C1.4,0,0.9,0.2,0.6,0.6S0,1.4,0,2v92c0,0.6,0.2,1.1,0.6,1.4S1.4,96,2,96z"></path><path fill="#FFA100" d="M218,336h116c0.6,0,1.1-0.2,1.4-0.6s0.6-0.9,0.6-1.4v-92c0-0.6-0.2-1.1-0.6-1.4s-0.9-0.6-1.4-0.6H218 c-0.6,0-1.1,0.2-1.4,0.6s-0.6,0.9-0.6,1.4v92c0,0.6,0.2,1.1,0.6,1.4S217.4,336,218,3 ...

# %% [markdown]
# There's a lot of stuff there! How can we navigate through it? Well, the `BeautifulSoup` library gives us a lot of tools for parsing this into some form we may want to use:

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting beautifulsoup4 (from bs4)
#   Downloading beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->bs4)
#   Downloading soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/luc/.local/lib/python3.11/site-packages (from beautifulsoup4->bs4) (4.15.0)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Downloading soupsieve-2.8-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4, bs4
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [bs4]
# Successfully installed beautifulsoup4-4.14.2 bs4-0.0.2 soupsieve-2.8

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(bbc.text)

print(soup.title)
# Out:
# <title data-rh="true">Home - BBC News</title>

# %% [markdown]
# `bs4` comes with a ton of useful tools for navigating the webpage - for example to get all the link in the page, we can just use:

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# https://www.bbc.co.uk
# #main-heading
# https://www.bbc.co.uk/accessibility/
# https://account.bbc.com/account?lang=en-GB&ptrt=https%3A%2F%2Fwww.bbc.co.uk%2Fnews
# https://www.bbc.co.uk/notifications
# https://www.bbc.co.uk
# https://www.bbc.co.uk/news
# https://www.bbc.co.uk/sport
# https://www.bbc.co.uk/weather
# https://www.bbc.co.uk/iplayer
# https://www.bbc.co.uk/sounds
# https://www.bbc.co.uk/bitesize
# https://www.bbc.co.uk/cbbc
# https://www.bbc.co.uk/cbeebies
# https://www.bbc.co.uk/food
# #global-navigation-more-menu
# #global-navigation-more-menu
# /search?d=NEWS_PS
# https://www.bbc.co.uk
# https://www.bbc.co.uk/news
# https://www.bbc.co.uk/sport
# https://www.bbc.co.uk/weather
# https://www.bbc.co.uk/iplayer
# https://www.bbc.co.uk/sounds
# https://www.bbc.co.uk/bitesize
# https://www.bbc.co.uk/cbbc
# https://www.bbc.co.uk/cbeebies
# https://www.bbc.co.uk/food
# #more-menu-button
# /news
# #product-navigation-menu
# /news
# /news/bbcindepth
# /news/topics/c2vdnvdg6xxt
# /news/topics/c1vw6q14rzqt
# /news/topics/cmj34zmwm1zt
# /news/uk
# /news/world
# /news/business
# /news/politics
# /news/entertainment_and_arts
# #product-navigation-more-menu
# /news/technology
# /news/science_and_environment
# /news/health
# /news/education
# /news/in_pictures
# /news/newsbeat
# /news/bbcverify
# /news/disability
# /news/england
# /news/northern_ireland
# /news/scotland
# /naidheachdan
# /news/wales
# /cymrufyw
# /news/regions
# /news/my
# None
# None
# /news/live/c2059g6757qt
# /news/politics
# /news/articles/c3eplk4047do
# /news/politics
# /weather/articles/cz0xvjrzp4eo
# /weather
# /weather/articles/cz0xvjrzp4eo#comments
# /news/articles/c993z32j4r4o
# /news/world/europe
# /news/articles/cg3ee303yxpo
# /news/world/asia
# /news/articles/cp85g86x0zgo
# /news/world/europe
# /news/articles/c891ze79j8no
# /news/northern_ireland/northern_ireland_politics
# /news/articles/c891ze79j8no#comments
# /news/articles/c4gz1qy30v5o
# /news/england/beds_bucks_and_herts
# /news/articles/ceq03r3z2eqo
# /news/england/dorset
# /news/articles/cvgv653v1vjo
# /news/world/us_and_canada
# /sport/boxing/articles/cwyprrlww9do
# /sport/boxing
# /sport/boxing/articles/cwyprrlww9do#comments
# /news/articles/c2emyz0zpxko
# /news/world/middle_east
# /news/articles/c5ylene693no
# /news/entertainment_and_arts
# /news/live/c2059g6757qt
# /news/politics
# /news/articles/c3eplk4047do
# /news/politics
# /weather/articles/cz0xvjrzp4eo
# /weather
# /weather/articles/cz0xvjrzp4eo#comments
# /news/articles/cg3ee303yxpo
# /news/world/asia
# /news/articles/cp85g86x0zgo
# /news/world/europe
# /news/articles/c4gz1qy30v5o
# /news/england/beds_bucks_and_herts
# /news/articles/ceq03r3z2eqo
# /news/england/dorset
# /news/articles/cvgv653v1vjo
# /news/world/us_and_canada
# /sport/boxing/articles/cwyprrlww9do
# /sport/boxing
# /sport/boxing/articles/cwyprrlww9do#comments
# /news/articles/c2emyz0zpxko
# /news/world/middle_east
# /news/articles/c5ylene693no
# /news/entertainment_and_arts
# /news/articles/c709ppwpw1wo
# /news/technology
# /news/live/c2059g6757qt
# /news/politics
# /news/articles/c3eplk4047do
# /news/politics
# /weather/articles/cz0xvjrzp4eo
# /weather
# /weather/articles/cz0xvjrzp4eo#comments
# /news/articles/cg3ee303yxpo
# /news/world/asia
# /news/articles/cp85g86x0zgo
# /news/world/europe
# /news/articles/c4gz1qy30v5o
# /news/england/beds_bucks_and_herts
# /news/articles/ceq03r3z2eqo
# /news/england/dorset
# /news/articles/cvgv653v1vjo
# /news/world/us_and_canada
# /sport/boxing/articles/cwyprrlww9do
# /sport/boxing
# /sport/boxing/articles/cwyprrlww9do#comments
# /news/articles/c2emyz0zpxko
# /news/world/middle_east
# /news/articles/c5ylene693no
# /news/entertainment_and_arts
# /news/articles/c709ppwpw1wo
# /news/technology
# /news/live/c2059g6757qt
# /news/politics
# /news/articles/c3eplk4047do
# /news/politics
# /weather/articles/cz0xvjrzp4eo
# /weather
# /weather/articles/cz0xvjrzp4eo#comments
# /news/articles/cg3ee303yxpo
# /news/world/asia
# /news/articles/cp85g86x0zgo
# /news/world/europe
# /news/articles/c4gz1qy30v5o
# /news/england/beds_bucks_and_herts
# /news/articles/ceq03r3z2eqo
# /news/england/dorset
# /news/articles/cvgv653v1vjo
# /news/world/us_and_canada
# /sport/boxing/articles/cwyprrlww9do
# /sport/boxing
# /sport/boxing/articles/cwyprrlww9do#comments
# /news/articles/c2emyz0zpxko
# /news/world/middle_east
# /news/articles/c5ylene693no
# /news/entertainment_and_arts
# /news/articles/c709ppwpw1wo
# /news/technology
# /news/live/c2059g6757qt
# /news/politics
# /news/articles/c3eplk4047do
# /news/politics
# /weather/articles/cz0xvjrzp4eo
# /weather
# /weather/articles/cz0xvjrzp4eo#comments
# /news/articles/cg3ee303yxpo
# /news/world/asia
# /news/articles/cp85g86x0zgo
# /news/world/europe
# /news/articles/c4gz1qy30v5o
# /news/england/beds_bucks_and_herts
# /news/articles/ceq03r3z2eqo
# /news/england/dorset
# /news/articles/cvgv653v1vjo
# /news/world/us_and_canada
# /sport/boxing/articles/cwyprrlww9do
# /sport/boxing
# /sport/boxing/articles/cwyprrlww9do#comments
# /news/articles/c2emyz0zpxko
# /news/world/middle_east
# /news/articles/c5ylene693no
# /news/entertainment_and_arts
# /news/articles/c709ppwpw1wo
# /news/technology
# /news/articles/crkl3d6pegpo
# /news/bbcindepth
# /news/articles/c709y0v8gkwo
# /sport/boxing/articles/c620q0vwxydo
# /sport/boxing
# /sport/boxing/articles/c620q0vwxydo#comments
# /news/articles/cy9pz4ry3d9o
# /news/entertainment_and_arts
# /news/articles/cq50nvq8znvo
# /news/world/us_and_canada
# /newsletters/zyxfdnb
# /news/videos/ceq08zjgr33o
# /news/videos/ckg1k6ej5lyo
# /news/videos/cx20zn57v3po
# /news/videos/c77zp26n5m1o
# /news/videos/cm2w4n093zeo
# /news/articles/cgr488xxwv1o
# /news/entertainment_and_arts
# /news/articles/cg7nxx7dl40o
# /news/england/birmingham_and_black_country
# /news/articles/c74jgvp1x49o
# /news/business
# /news/articles/c2dr6y0w3rjo
# /news/world/asia
# /news/articles/cn7e4m48gdro
# /news/england/coventry_and_warwickshire
# /news/articles/c0ex0y0p31jo
# /news/world/europe
# /news/articles/cwypzdgwg1yo
# /news/world/latin_america
# /news/articles/cwypzdgwg1yo#comments
# /news/articles/cp85g86x0zgo
# /news/articles/ceq03r3z2eqo
# /news/articles/c3eplk4047do
# /news/articles/c5ylene693no
# /news/articles/c4gz1qy30v5o
# /news/articles/c709ppwpw1wo
# /news/articles/cg3ee303yxpo
# /news/articles/cgr488xxwv1o
# /news/articles/cy9pz4ry3d9o
# /news/articles/cew4e927e05o
# /news/10628994
# /iplayer/live/bbcnews
# /sounds/play/live:bbc_sounds_news
# /sounds/play/m002m0fz
# /sounds/play/w3ct8byq
# /iplayer/episodes/p0fty7vj/watch/p0mfcgkv?at_mid=7OA3QgPycJ&at_campaign=The_Night_Manager_S2_Trailer&at_medium=display_ad&at_campaign_type=owned&at_nation=NET&at_audience_id=SS&at_product=iplayer&at_brand=p0fty7vj&at_ptr_name=bbc&at_ptr_type=media&at_format=image&at_objective=consumption&at_link_title=The_Night_Manager_S2_Trailer&at_bbc_team=BBC
# https://www.bbc.co.uk/
# /sounds/play/m002n36k?at_mid=l08qSv2Fcz&at_campaign=Ready_to_Talk_with_Emma_Barnett_Chris_McCausland&at_medium=display_ad&at_campaign_type=owned&at_nation=NET&at_audience_id=SS&at_product=sounds&at_brand=p0mdcpkb&at_ptr_name=bbc&at_ptr_type=media&at_format=image&at_objective=consumption&at_link_title=Ready_to_Talk_with_Emma_Barnett_Chris_McCausland&at_bbc_team=BBC
# https://www.bbc.co.uk/
# /iplayer/episodes/m002hzfm/watch/p0mf42py?at_mid=fVIsteMxng&at_campaign=BBC_Trailers_Prisoner_951&at_medium=display_ad&at_campaign_type=owned&at_nation=NET&at_audience_id=SS&at_product=iplayer&at_brand=m002hzfm&at_ptr_name=bbc&at_ptr_type=media&at_format=image&at_objective=consumption&at_link_title=BBC_Trailers_Prisoner_951&at_bbc_team=BBC
# https://www.bbc.co.uk/
# /sounds/play/p0mg32hc?at_mid=yHcNQk1XPA&at_campaign=Strange_But_True_Crime_Act_of_Treeson&at_medium=display_ad&at_campaign_type=owned&at_nation=NET&at_audience_id=SS&at_product=sounds&at_brand=p0l3x7rp&at_ptr_name=bbc&at_ptr_type=media&at_format=image&at_objective=consumption&at_link_title=Strange_But_True_Crime_Act_of_Treeson&at_bbc_team=BBC
# https://www.bbc.co.uk/
# /iplayer/episode/m002m3tl/mr-burton?at_mid=FCqiGdjR3M&at_campaign=Mr_Burton&at_medium=display_ad&at_campaign_type=owned&at_nation=WLS&at_audience_id=SS&at_product=iplayer&at_brand=m002m3tl&at_ptr_name=bbc&at_ptr_type=media&at_format=image&at_objective=consumption&at_link_title=Mr_Burton&at_bbc_team=BBC
# https://www.bbc.co.uk/
# /sounds/play/p0mg3g7m?at_mid=8exQGJoCj4&at_campaign=Complex_with_Kimberley_Wilson_Are_you_too_empathetic&at_medium=display_ad&at_campaign_type=owned&at_nation=NET&at_audience_id=SS&at_product=sounds&at_brand=p0mcyd0k&at_ptr_name=bbc&at_ptr_type=media&at_format=image&at_objective=consumption&at_link_title=Complex_with_Kimberley_Wilson_Are_you_too_empathetic&at_bbc_team=BBC
# https://www.bbc.co.uk/
# /iplayer/episode/b007cdz8?at_mid=2P393jit57&at_campaign=Bridget_Joness_Diary&at_medium=display_ad&at_campaign_type=owned&at_nation=NET&at_audience_id=SS&at_product=iplayer&at_brand=b007cdz8&at_ptr_name=bbc&at_ptr_type=media&at_format=image&at_objective=consumption&at_link_title=Bridget_Joness_Diary&at_bbc_team=BBC
# https://www.bbc.co.uk/
# /sport
# /sport/boxing/articles/cwyprrlww9do
# /sport/boxing
# /sport/boxing/articles/cwyprrlww9do#comments
# /sport/cricket/articles/cj97kdknvnwo
# /sport/cricket
# /sport/cricket/articles/cj97kdknvnwo#comments
# /sport/football/articles/cp3xgvw0vd2o
# /sport/football/teams/italy
# /sport/football/articles/cp3xgvw0vd2o#comments
# /sport/boxing/articles/c620q0vwxydo
# /sport/boxing
# /sport/boxing/articles/c620q0vwxydo#comments
# /sport/football/articles/c0kp0zpmxe2o
# /sport/football
# /sport/extra/0g73ogf816/ultimate-ashes-25-26-grounds-guide
# /sport/tennis/articles/clyz0yd0ello
# /sport/tennis
# /sport
# /news/my
# /news/20039682
# /news/articles/cp08467m0zzo
# /news/help-41670342
# https://www.instagram.com/bbcnews/
# https://www.tiktok.com/@bbcnews?lang=en
# https://www.facebook.com/bbcnews
# https://twitter.com/BBCNews
# /iplayer/episode/m0028vwc?at_mid=GduciS9BbR&at_campaign=Wild_Cherry&at_medium=display_ad&at_campaign_type=owned&at_nation=NET&at_audience_id=SS&at_product=iplayer&at_brand=m0028vw8&at_ptr_name=bbc&at_ptr_type=media&at_format=image&at_objective=consumption&at_link_title=Wild_Cherry&at_bbc_team=BBC
# https://www.bbc.co.uk/iplayer/watchlist
# /iplayer/episode/m002mf6r?at_mid=U4GG3BP1vZ&at_campaign=Celebrity_MasterChef_S20_E1&at_medium=display_ad&at_campaign_type=owned&at_nation=NET&at_audience_id=SS&at_product=iplayer&at_brand=b007mtf0&at_ptr_name=bbc&at_ptr_type=media&at_format=image&at_objective=consumption&at_link_title=Celebrity_MasterChef_S20_E1&at_bbc_team=BBC
# https://www.bbc.co.uk/iplayer/watchlist
# /iplayer/episode/m002mdmp?at_mid=Mjmxl3RLrO&at_campaign=Antiques_Road_Trip_S31_E6&at_medium=display_ad&at_campaign_type=owned&at_nation=NET&at_audience_id=SS&at_product=iplayer&at_brand=b00xgqvf&at_ptr_name=bbc&at_ptr_type=media&at_format=image&at_objective=consumption&at_link_title=Antiques_Road_Trip_S31_E6&at_bbc_team=BBC
# https://www.bbc.co.uk/iplayer/watchlist
# /iplayer/episode/m002mggr?at_mid=1nm6DE8JDk&at_campaign=Jools_Hollands_New_Orleans_Jukebox&at_medium=display_ad&at_campaign_type=owned&at_nation=NET&at_audience_id=SS&at_product=iplayer&at_brand=m002mggr&at_ptr_name=bbc&at_ptr_type=media&at_format=image&at_objective=consumption&at_link_title=Jools_Hollands_New_Orleans_Jukebox&at_bbc_team=BBC
# https://www.bbc.co.uk/iplayer/watchlist
# https://www.bbc.co.uk
# https://www.bbc.co.uk/news
# https://www.bbc.co.uk/sport
# https://www.bbc.co.uk/weather
# https://www.bbc.co.uk/iplayer
# https://www.bbc.co.uk/sounds
# https://www.bbc.co.uk/bitesize
# https://www.bbc.co.uk/cbbc
# https://www.bbc.co.uk/cbeebies
# https://www.bbc.co.uk/food
# https://www.bbc.co.uk/usingthebbc/terms
# https://www.bbc.co.uk/aboutthebbc
# https://www.bbc.co.uk/usingthebbc/privacy
# https://www.bbc.co.uk/usingthebbc/cookies
# https://www.bbc.co.uk/accessibility
# https://www.bbc.co.uk/iplayer/guidance
# https://www.bbc.co.uk/contact
# https://www.bbc.co.uk/contact/complaints
# https://www.bbc.co.uk/bbcnewsletter
# https://www.bbc.co.uk/editorialguidelines/guidance/feeds-and-links

# %% [markdown]
# Most of these are hyperlinks to other parts of the website - but how can we filter to *only* these entries? Well - we can use regex!

# %%
links = [link.get('href') for link in soup.find_all('a')]

valid_links = [link for link in links if link is not None]

# Now pattern match
only_hypers = [s for s in valid_links if re.compile("https://www\..*").match(s)]
print(only_hypers)
# Out:
# ['https://www.bbc.co.uk', 'https://www.bbc.co.uk/accessibility/', 'https://www.bbc.co.uk/notifications', 'https://www.bbc.co.uk', 'https://www.bbc.co.uk/news', 'https://www.bbc.co.uk/sport', 'https://www.bbc.co.uk/weather', 'https://www.bbc.co.uk/iplayer', 'https://www.bbc.co.uk/sounds', 'https://www.bbc.co.uk/bitesize', 'https://www.bbc.co.uk/cbbc', 'https://www.bbc.co.uk/cbeebies', 'https://www.bbc.co.uk/food', 'https://www.bbc.co.uk', 'https://www.bbc.co.uk/news', 'https://www.bbc.co.uk/sport', 'https://www.bbc.co.uk/weather', 'https://www.bbc.co.uk/iplayer', 'https://www.bbc.co.uk/sounds', 'https://www.bbc.co.uk/bitesize', 'https://www.bbc.co.uk/cbbc', 'https://www.bbc.co.uk/cbeebies', 'https://www.bbc.co.uk/food', 'https://www.bbc.co.uk/', 'https://www.bbc.co.uk/', 'https://www.bbc.co.uk/', 'https://www.bbc.co.uk/', 'https://www.bbc.co.uk/', 'https://www.bbc.co.uk/', 'https://www.bbc.co.uk/', 'https://www.instagram.com/bbcnews/', 'https://www.tiktok.com/@bbcnews?lang=en', 'https://www.facebook.com/bbcnews', 'https://www.bbc.co.uk/iplayer/watchlist', 'https://www.bbc.co.uk/iplayer/watchlist', 'https://www.bbc.co.uk/iplayer/watchlist', 'https://www.bbc.co.uk/iplayer/watchlist', 'https://www.bbc.co.uk', 'https://www.bbc.co.uk/news', 'https://www.bbc.co.uk/sport', 'https://www.bbc.co.uk/weather', 'https://www.bbc.co.uk/iplayer', 'https://www.bbc.co.uk/sounds', 'https://www.bbc.co.uk/bitesize', 'https://www.bbc.co.uk/cbbc', 'https://www.bbc.co.uk/cbeebies', 'https://www.bbc.co.uk/food', 'https://www.bbc.co.uk/usingthebbc/terms', 'https://www.bbc.co.uk/aboutthebbc', 'https://www.bbc.co.uk/usingthebbc/privacy', 'https://www.bbc.co.uk/usingthebbc/cookies', 'https://www.bbc.co.uk/accessibility', 'https://www.bbc.co.uk/iplayer/guidance', 'https://www.bbc.co.uk/contact', 'https://www.bbc.co.uk/contact/complaints', 'https://www.bbc.co.uk/bbcnewsletter', 'https://www.bbc.co.uk/editorialguidelines/guidance/feeds-and-links']

# %% [markdown]
# Of course, we now have more links we can iterate over and build a network of how the BBC news website works (please put a delay in otherwise you'll get in trouble!)

# %% [markdown]
# ## Image Processing
#
# We can also get all the images from the BBC website with a little bit of work:

# %%
imgs = [img.get('data-src') or img.get('src') for img in soup.find_all('img')]

print(imgs)
# Out:
# ['https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/2366/live/6930ea80-c3d1-11f0-bdbe-6f7df1044786.png', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/8ceb/live/7f570fd0-671d-11f0-af20-030418be2ca5.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/6681/live/01524a10-c39c-11f0-a624-43243f904594.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/5661/live/649da6d0-c30d-11f0-a534-edf3bf729187.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/b780/live/70356510-c3c0-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/9bdf/live/8c8e3e90-c3d8-11f0-ae46-bd64331f0fd4.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/9adf/live/1b57e1d0-c311-11f0-a534-edf3bf729187.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/327f/live/993c73c0-c3b8-11f0-8456-eff94716b162.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/9d61/live/f915bed0-82ec-11f0-a819-c948892e2dca.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/c05a/live/46ff00a0-c3d6-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/6e4f/live/d6a98130-c3c2-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/7a12/live/5905fee0-b8b2-11f0-aa13-0b0479f6f42a.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/7548/live/d5ddcff0-c3c6-11f0-8456-eff94716b162.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/2366/live/6930ea80-c3d1-11f0-bdbe-6f7df1044786.png', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/8ceb/live/7f570fd0-671d-11f0-af20-030418be2ca5.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/6681/live/01524a10-c39c-11f0-a624-43243f904594.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/b780/live/70356510-c3c0-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/9bdf/live/8c8e3e90-c3d8-11f0-ae46-bd64331f0fd4.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/327f/live/993c73c0-c3b8-11f0-8456-eff94716b162.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/9d61/live/f915bed0-82ec-11f0-a819-c948892e2dca.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/c05a/live/46ff00a0-c3d6-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/6e4f/live/d6a98130-c3c2-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/7a12/live/5905fee0-b8b2-11f0-aa13-0b0479f6f42a.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/7548/live/d5ddcff0-c3c6-11f0-8456-eff94716b162.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/77ef/live/8ff76060-c3bb-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/2366/live/6930ea80-c3d1-11f0-bdbe-6f7df1044786.png', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/8ceb/live/7f570fd0-671d-11f0-af20-030418be2ca5.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/6681/live/01524a10-c39c-11f0-a624-43243f904594.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/b780/live/70356510-c3c0-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/9bdf/live/8c8e3e90-c3d8-11f0-ae46-bd64331f0fd4.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/327f/live/993c73c0-c3b8-11f0-8456-eff94716b162.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/9d61/live/f915bed0-82ec-11f0-a819-c948892e2dca.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/c05a/live/46ff00a0-c3d6-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/6e4f/live/d6a98130-c3c2-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/7a12/live/5905fee0-b8b2-11f0-aa13-0b0479f6f42a.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/7548/live/d5ddcff0-c3c6-11f0-8456-eff94716b162.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/77ef/live/8ff76060-c3bb-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/2366/live/6930ea80-c3d1- ...

# %% [markdown]
# Now we have a very typical problem in programming - our result is good, but not quite there:
#
# * We have this `/standard/\d+/` thing in each of the urls - this is a bit of a funny web thing that lets us put a number in here to get an image with the specified width. If we choose a value for this width we need to replace this with that number to get a valid image. It can sometimes be `{width}` or `/{width}/` depending on the website.
# * We have a number of duplicate images. We can fix this by converting to a set and back
#
# For this, we can do it in two steps:

# %%
# Remove Nones
imgs = [a for a in imgs if a]

# Replace width in image URLs
desired_width = 400

def replace_width(url, new_width):
    return re.sub(r'/standard/\d+/', f'/standard/{new_width}/', url)


imgs = list(set([replace_width(url, desired_width) for url in imgs]))


print(imgs)
# Out:
# ['https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/dc04/live/25cfa4d0-b976-11f0-b2a1-6f537f66f9aa.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/61c8/live/f47acae0-c15e-11f0-8456-eff94716b162.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/0d6b/live/4f45a5b0-c3a5-11f0-ae46-bd64331f0fd4.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/7a60/live/83bf80d0-c0b3-11f0-8a6c-bdcd4bb2f081.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/865a/live/c74350d0-c0d5-11f0-8456-eff94716b162.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/ee89/live/68109fa0-8946-11ee-952c-5f8de97ee99b.png', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/e6d1/live/2055eb70-c1f7-11f0-8456-eff94716b162.png', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/d008/live/c98662c0-c174-11f0-8456-eff94716b162.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/9adf/live/1b57e1d0-c311-11f0-a534-edf3bf729187.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/fe03/live/463781d0-c39d-11f0-ae46-bd64331f0fd4.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/2014/live/61fe94e0-c3b0-11f0-ae46-bd64331f0fd4.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/b780/live/70356510-c3c0-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/4420/live/621fdfb0-b000-11f0-b2a1-6f537f66f9aa.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/8ceb/live/7f570fd0-671d-11f0-af20-030418be2ca5.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/ce64/live/dcbd20a0-bbf1-11f0-ae46-bd64331f0fd4.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/62cd/live/eb0c77e0-c151-11f0-ae46-bd64331f0fd4.jpg', 'https://ichef.bbci.co.uk/images/ic/480x270/p0j72y80.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/6802/live/223886f0-8946-11ee-952c-5f8de97ee99b.png', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/5c63/live/f280e8f0-bee8-11f0-ae46-bd64331f0fd4.jpg', 'https://sb.scorecardresearch.com/p?c1=2&c2=17986528&cs_ucfr=0&cv=2.0&cj=1', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/9d61/live/f915bed0-82ec-11f0-a819-c948892e2dca.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/3628/live/53c130f0-8946-11ee-952c-5f8de97ee99b.png', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/aa8e/live/21542440-c339-11f0-bcfc-3bbfba5b47bf.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/c052/live/0cced1b0-c3ab-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/4b2b/live/b3323b20-c37c-11f0-ae46-bd64331f0fd4.jpg', 'https://ichef.bbci.co.uk/images/ic/480x270/p0lgrqgm.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/ba63/live/0f33d1b0-c3d5-11f0-bbb8-f506e20a7d44.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/7a12/live/5905fee0-b8b2-11f0-aa13-0b0479f6f42a.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/47a1/live/62dff990-c3c3-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/a02a/live/aa406520-c3b1-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/88d5/live/b5eee920-c387-11f0-8456-eff94716b162.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/2a45/live/8d666100-c165-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/9bdf/live/8c8e3e90-c3d8-11f0-ae46-bd64331f0fd4.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/5661/live/649da6d0-c30d-11f0-a534-edf3bf729187.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/2366/live/6930ea80-c3d1-11f0-bdbe-6f7df1044786.png', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/c05a/live/46ff00a0-c3d6-11f0-8669-5560f5c90fbe.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/7548/live/d5ddcff0-c3c6-11f0-8456-eff94716b162.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/6f27/live/71d03680-be74-11f0-ae46-bd64331f0fd4.jpg', 'https://ichef.bbci.co.uk/ace/standard/400/cpsprodpb/fad3/live/04679c30-c132-11f0-ae46-bd64331 ...

# %% [markdown]
# Now we have a list of all the images, we can load them using a library like `PIL`:

# %%
from PIL import Image
from urllib.request import urlopen

all_imgs = []

for url in imgs:
    img = Image.open(urlopen(url))
    all_imgs.append(img)

# %% [markdown]
# We can check if this has worked by showing the first image:

# %%
all_imgs[0].show()

# %% [markdown]
# Now let's create a board for all the images we've found. This is fairly complex and to be fair took a load of trial and error on my part!

# %%
# Get the height and width of one image
w = all_imgs[0].size[0]
h = all_imgs[0].size[1]

# Calculate the height and width of a 4 wide grid of all the images
w_all = w * 4
h_all = math.ceil(h * len(all_imgs) / 4)

# Create a new image with the dimensions above
im = Image.new("RGBA", (w_all, h_all))

# Iterate over the list of images and their index, adding the image to each spot
for idx, image in enumerate(all_imgs):
    im.paste(image, ((idx % 4) * w, (idx // 4) * h))

# Save the image
im.save("grid.png")
# Show the image
im.show()

# %% [markdown]
# Phew! Let's switch gears and look at how to use this in a different way.
#
# ## Sending Emails with Python
#
# Say we have the above program that scrapes the BBC news homepage, gets all the images and combines them into a grid. What if we want to send this via email? Well, with a bit of work and help from our mail provider we can:

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.image import MIMEImage
from email.mime.multipart import MIMEMultipart

# First, we need to read the images as bytes
with open("./grid.png", 'rb') as f:
        img_data = f.read()

from_email ='<from_email address>' 
to_email = '<destination_email address>'

msg = MIMEMultipart()
msg['Subject'] = 'This is a test email'
msg['From'] = from_email
msg['To'] = to_email 

text = MIMEText("This is a test email")
msg.attach(text)

image = MIMEImage(img_data, name="grid.png")
msg.attach(image)

server = smtplib.SMTP("smtp.gmail.com", 587)
server.starttls()

server.login(from_email, '<gmail auth key>')

server.sendmail(from_email, to_email, msg.as_string())
server.quit()
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[56], line 27
#      24 server = smtplib.SMTP("smtp.gmail.com", 587)
#      25 server.starttls()
# ---> 27 server.login(from_email, '<gmail auth key>')
#      29 server.sendmail(from_email, to_email, msg.as_string())
#      30 server.quit()
#
# File ~/micromamba/envs/CE/lib/python3.11/smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File ~/micromamba/envs/CE/lib/python3.11/smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# --> 739     (code, resp) = self.auth(
#     740         authmethod, getattr(self, method_name),
#     741         initial_response_ok=initial_response_ok)
#     742     # 235 == 'Authentication successful'
#     743     # 503 == 'Error: already authenticated'
#     744     if code in (235, 503):
#
# File ~/micromamba/envs/CE/lib/python3.11/smtplib.py:662, in SMTP.auth(self, mechanism, authobject, initial_response_ok)
#     660 if code in (235, 503):
#     661     return (code, resp)
# --> 662 raise SMTPAuthenticationError(code, resp)
#
# SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials 5b1f17b1804b1-47787e36ca3sm347033195e9.5 - gsmtp')

# %% [markdown]
# # Exercises
#
# ## Pretty Formatting
#
# Write a function that takes in a dictionary of values and prints the key value pairs in the following format:
#
# ```
# key         | value
# key         | value
# key         | value
# ```

# %%
# Code Here!

# %% [markdown]
# ## Email RegEx
#
# Emails are in the form username@domain.tld. Write a RegEx pattern that matches emails in this form

# %%
# Code Here!

def email_check(email_pattern):
    test_emails = [
        "username@domain.tld",
        "test.gmail@gmail.com",
        "invalid-email@domain",
        "another.invalid.email@domain..com",
    ]
    pass_fails = []
    for email in test_emails:
        if re.fullmatch(email_pattern, email):
            pass_fails.append(True)
        else:
            pass_fails.append(False)
    
    print(pass_fails)
    if pass_fails == [True, True, False, False]:
        print("All tests passed!")
        return
    
    else:
        print("Some tests failed.")

# emaul_pattern = r""
# email_check(email_pattern)
# Out:
# [True, True, False, False]
# All tests passed!

# %% [markdown]
# ## Web Scraping
#
# The [official top 40 singles chart](https://www.officialcharts.com/charts/uk-top-40-singles-chart/") contains a table with all the top 40 hits in the UK. Use `BeautifulSoup` to scrape this website to get the top 40 singles in a human readable format (`1. THE FATE OF OPHELIA - TAYLOR SWIFT, 2. GOLDEN - HUNTR/X/EJAE/AUDREY NUNA/REI` etc).
#
# You'll need to use the below query to get started, where `chart_soup` is the output of `BeautifulSoup`:
#
# `tracks = chart_soup.find_all("div", {"class": "track"})`

# %%
# Code Here!
